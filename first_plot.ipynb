# %%
import numpy as np
import matplotlib.pyplot as plt

print("TK Research Python is online 🧪⚛️")

x = np.linspace(0, 10, 200)
y = np.sin(x)

plt.plot(x, y)
plt.title("First Scientific Plot")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.show()
# Out:
# TK Research Python is online 🧪⚛️
